# %%
import pandas as pd

# %%
import csv
with open('apartment_list_with_valid_location.csv', newline='') as csvfile:
    data_apartments = list(csv.reader(csvfile))

# %%
with open('metro_stations.csv', newline='') as csvfile:
    data_metro = list(csv.reader(csvfile))

# %%
name_apartments = []
distance = []
i =0
for y in data_apartments:
    x = []
    distance.append(x)
k =0

# %%
from geopy.distance import geodesic

# %%
check =0
for i in data_apartments:
    if check ==0 :
        check =1
        #=="latitude":
        continue
    one = [i[2],i[1]]
    name_apartments.append(i[0])
    k=-1
    for j in data_metro:
        if k ==-1:
            k = k+1
            continue
        k=k+1
        two = [j[1],j[2]]
        t = geodesic(one,two).miles
        distance[k].append(t)
        
        #distance[k].append('6')

# %%
distance
# Out:
# [[],
#  [6.057759438101568,
#   4.665132044143041,
#   14.053994715620945,
#   13.562313294601033,
#   7.797713758345663,
#   10.622920864641808,
#   12.637922203309172,
#   9.277172013671999,
#   10.467947673637548,
#   10.641285726296548,
#   15.554574560641434,
#   18.394574397661927,
#   23.112566068219074,
#   15.43805255322158,
#   8.200343809027302,
#   6.646368575898349,
#   11.049134593619554,
#   9.41894081881941,
#   5.69243860371751,
#   8.674776790622275,
#   3.7585500292013547,
#   1.6763380191679473,
#   8.230187814464488,
#   2.7111423424667755,
#   13.380742714785306,
#   2.548544296401925,
#   0.17657464373736964,
#   2.153207374741926,
#   0.16503824717009463,
#   4.00969536388036,
#   19.49101783507714,
#   7.941326051447888,
#   17.0016609172243,
#   12.673983048574236,
#   4.202504148637903,
#   18.483082261039307,
#   15.228413437298684,
#   7.586979489097401,
#   7.70650786994804,
#   3.6191586920975296,
#   7.865338724634447,
#   9.106646279467071,
# ...

# %%
df = pd.DataFrame(distance)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-852d3605e3c4> in <module>
# ----> 1 df = pd.DataFrame(distance)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# ...

# %%
distance

# %%
pip install pandas

# %%
pip install selenium

# %%
df.to_csv('~/Desktop/ivyhomes/metro_distance_data.csv')

# %%
miles = geodesic(one,two).miles
f"Miles: {miles:.2f}"

# %%
miles

# %%
from array import *

# %%
for x in data_apartments:

# %%
x

# %%
rw = [data[5][1],data[5][2]]

# %%
rw
