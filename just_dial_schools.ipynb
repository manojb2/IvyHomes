# %%
pip install webdriver_manager
# Out:
# Requirement already satisfied: webdriver_manager in ./.local/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: configparser in ./.local/lib/python3.8/site-packages (from webdriver_manager) (5.0.2)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from webdriver_manager) (2.22.0)
# Requirement already satisfied: crayons in ./.local/lib/python3.8/site-packages (from webdriver_manager) (0.4.0)
# Requirement already satisfied: colorama in /usr/lib/python3/dist-packages (from crayons->webdriver_manager) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in ./.local/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from selenium) (1.25.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.local/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.16.5 in ./.local/lib/python3.8/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager


import pandas as pd
import time
import os

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.local/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in ./.local/lib/python3.8/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
def strings_to_num(argument): 
    
    switcher = { 
        'dc': '+',
        'fe': '(',
        'hg': ')',
        'ba': '-',
        'acb': '0', 
        'yz': '1', 
        'wx': '2',
        'vu': '3',
        'ts': '4',
        'rq': '5',
        'po': '6',
        'nm': '7',
        'lk': '8',
        'ji': '9'
    } 
    
    return switcher.get(argument, "nothing")

# %%
link = "https://www.justdial.com/Bangalore/Schools/nct-10422444/page-"

# %%
 import re

# %%
import requests

# %%
nameList = []
addressList = []
numbersList = []
votesList =[]
ratingsList = []
latitudeList = []
longitudeList = []
    #tempList=[]

# %%
p =1
while p<51:
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(link+ str(p))
    p=p+1
    driver.implicitly_wait(10)
    from selenium.webdriver.remote.webelement import WebElement
    SCROLL_PAUSE_TIME = 3

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    i=1
    y = 2000
    while i<15:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight-2500);")
        i=i+1
        y=y+2000
        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        
        
        
    storeDetails = driver.find_elements_by_class_name('store-details')


   

    for i in range(len(storeDetails)):

        name = storeDetails[i].find_element_by_class_name('lng_cont_name').text
        address = storeDetails[i].find_element_by_class_name('cont_fl_addr').get_attribute('innerHTML')
        contactList = storeDetails[i].find_elements_by_class_name('mobilesv')
        temp = storeDetails[i].find_elements_by_class_name('rating_div')[1].get_attribute('text')
        temp=temp.replace("\t","")
        temp=temp.replace("\n","")
        elem = storeDetails[i].find_element_by_class_name('rating_div').get_attribute('href')
        ratings = temp[:3]
        votes = temp[3:]
        #votes = votes.replace("\n","")
        #ratings = storeDetails[i].find_elements_by_class_name('rating_div')[1].get_attribute('text')
        s = requests.Session()

        url = "https://www.justdial.com/functions/maps.php"

        hdr = {
                'accept': 'application/json, text/javascript, */*; q=0.01',
                'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36',
                'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'origin': 'https://www.justdial.com',
                'referer': elem,
                'accept-encoding': 'gzip, deflate, br',
                'accept-language': 'en-US,en;q=0.9'
                }

        try:
            s1 = re.search(r'/080(.*?)_BZDET', elem).group(1)
            s1 = s1.replace("-",".")
            s1 = "080" + s1;
            formdata = {
                    'doc': s1
                    }

            resp = s.post(url, headers=hdr, data=formdata)
            loc = resp.text
            try:
                latitude = re.search(r'l":"(.*?)","',loc).group(1)
            except AttributeError:
                latitude = re.search(r'l":"(.*?)","',loc)
            try:
                longitude = re.search(r'n":"(.*?)"}',loc).group(1)
            except AttributeError:
                longitude = re.search(r'n":"(.*?)"}',loc)
        except AttributeError:
                s1 = re.search(r'/080(.*?)_BZDET', elem)
        
        

        myList = []

        for j in range(len(contactList)):

            myString = contactList[j].get_attribute('class').split("-")[1]

            myList.append(strings_to_num(myString))

        nameList.append(name)
        addressList.append(address)
        numbersList.append("".join(myList))
        votesList.append(votes)
        ratingsList.append(ratings)
        latitudeList.append(latitude)
        longitudeList.append(longitude)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/home/manoj/.wdm/drivers/chromedriver/linux64/91.0.4472.101/chromedriver] found in cache

# %%
data = {'Company Name':nameList,
        #'temp':tempList,
        'Address': addressList,
        'Phone':numbersList,
        'votes':votesList,
        'ratings':ratingsList,
        'latitude':latitudeList,
        'longitude':longitudeList
        
       }

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                       Company Name  \
# 0          Karnataka Public School
# 1    Chistiya International Scho..
# 2    Silicon City Academy Of Sec..
# 3                 Sai Vidya Mandir
# 4             Carmel Public School
# ..                             ...
# 945  Royale Concorde Internation..
# 946        Aryan Presidency School
# 947      Deva Matha Central School
# 948  Bangalore School Of Speech ..
# 949        St. Xaviers High School
#
#                                                Address               Phone  \
# 0    Chokkanahalli Village, Hegde Nagar, Bangalore ...         07947396714
# 1    Gunjur, Whitefield-Sarjapur Road, Varthur, Ban...         07947157165
# 2    Silicon City Educational Trust, Kumar Nursery,...         07947154306
# 3    Bettahalasur, Bettahalsur, Bangalore - 562157,...         07947161754
# 4    No 2, 5th Cross , M S Layout, Jarganahalli, Jp...         07947161557
# ..                                                 ...                 ...
# 945  No.81/1, Hongasandra, Begur Road, Bangalore - ...  +(91)-080-25742060
# 946  No.283, 13th Main, Vinayaka Layout, 2nd Stage,...   +(91)-80-23391472
# 947  #2, Defence Layout, Vidyaranyapura, Bangalore ...   +(91)-80-23643752
# 948  No.529, 16th A Cross, 3rd Main, Hsr Layout Sec...  +(91)-080-41688713
# 949     Tasker Town, Shivaji Nagar, Bangalore - 560051   +(91)-80-22866287
#
#         votes ratings         latitude        longitude
# 0      2Votes     3.5        13.071708        77.633626
# 1    165Votes     4.2       12.9210676        77.738818
# 2    320Votes     4.3       12.8812062       77.5689372
# 3     34Votes     4.9       13.1586248       77.6126443
# 4     81Votes     4.3  12.902639055556  77.576286444444
# ..        ...     ...              ...              ...
# 945  125Votes     3.7       12.8907043        77.625737
# 946  124Votes     3.9       12.9624757       77.5077977
# 947  124Votes     3.9       13.0841303       77.5570298
# 948  123Votes     4.2       12.9124272        77.649282
# 949  122Votes     4.0       12.9869826       77.6007812
#
# [950 rows x 7 columns]

# %%
df.to_csv('~/Desktop/ivyhomes/just_dial_Schools_data.csv')
